# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
df = pd.read_csv("polynomial regression.csv",sep=",")

# %%
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
#verisetimize bir bakalım
plt.scatter(df['Level'],df['Salary'])
plt.xlabel('Deneyim (yıl)')
plt.ylabel('Maaş')
plt.savefig('1.png', dpi=300)
plt.show()

# %%
#Görüldüğü gibi doğrusal bir yapıda dağılmıyor veriler
#Eğer biz bu veri setine linear regression uygularsak hiç uygun olmayan bir tahmin çizgisi görürüz

reg = LinearRegression()
reg.fit(df[['Level']],df['Salary'])
plt.xlabel('Deneyim (yıl)')
plt.ylabel('Maaş')
plt.scatter(df['Level'],df['Salary'])

xekseni = df['Level']
yekseni = reg.predict(df[['Level']])
plt.plot(xekseni,yekseni,color="green", label="linear regression")
plt.legend()
plt.show()

# %% [markdown]
# Tahmin için çok kötü bir doğru demekki neymiş:Bu veriseti için linear regresyon uygulamak doğru değilmiş.
# Unutmayın verisetinize göre model seçeceksiniz.Öncelikle verisetinize çok iyi hakim olmalı ve bilmelisiniz

# %% [markdown]
# *Bu veri seti için regression çeşitlerinden polynomial regression uygulanması gerektiğine karar verdik.Şimdi nasıl uyguladığımıza bakalım*

# %% [markdown]
# X değerimizi polinom yukarıdaki fonksiyonuna uyacak şekilde uyarlanmasını sağlıyoruz
# Yani => 1,x,x^2(N=2) şeklinde

# %%
polynomial_regression = PolynomialFeatures(degree = 4)
x_polynomial = polynomial_regression.fit_transform(df[['Level']])

# %%
#regression model nesnemiz olan reg nesnemizi oluşturup bunun fit metodunu çağırarak x_polynomial ve y
#yani regresyon modelimizi mevcut gerçek verilerle eğitiyoruz:
reg = LinearRegression()
reg.fit(x_polynomial,df['Salary'])
# Out:
# LinearRegression()

# %% [markdown]
# **Artık modelimiz hazır ve eğitilmiş, şimdi eldeki verilere göre modelimiz nasıl bir sonuç grafiği oluşturuyor onu görelim:**

# %%
y_head = reg.predict(x_polynomial)
plt.plot(df['Level'],y_head,color="red", label="polynomial regression")
plt.legend()

#verisetimizi de noktasal olarak scatter edelim de görelim bakalım uymuş mu polynomial regression:
plt.scatter(df['Level'],df['Salary'])
plt.show()

# %% [markdown]
# Gördüğünüz gibi kesinlikle uymuş diyebiliriz, polynomial regression doğru bir seçim.Şimdi bir de N=3 veya N=4 yapıp görelim
# polinom derecesini arttırdığımızda daha güzel fit edecek mi acaba?

# %%
x_polynomial1 = polynomial_regression.fit_transform([[4.5]])
reg.predict(x_polynomial1)
# Out:
# array([109582.14962125])

# %% [markdown]
# **Alacağı maaş çok güzel bir şekilde şirket politikasına fit etmiş oluyor. hakkı yenmeden!**

# %%
x_polynomial2 = polynomial_regression.fit_transform([[4.5],[6.7],[5.6]])
reg.predict(x_polynomial2)
# Out:
# array([109582.14962125, 167442.36756993, 134216.49417253])
